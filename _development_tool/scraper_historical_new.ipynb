# %%
from datetime import datetime
import pandas as pd
import requests
import zipfile
import sqlalchemy
import src.config as config

data_path = config.PL_HISTORICAL_DATA

# %%
db = sqlalchemy.create_engine(
    config.DATABASE_ENGINE,
)
district_df = pd.read_sql('district', db)
province_df = pd.read_sql('province', db)

# %%
def parse_data(filename, zip_file):
    try:
        with zip_file.open(filename) as my_file:
            raw_df = pd.read_csv(my_file, encoding='cp1250', sep=';')
    except UnicodeDecodeError:
        with zip_file.open(filename) as my_file:
            raw_df = pd.read_csv(my_file, encoding='utf8', sep=';')
    return raw_df

# %%
get_response = requests.get(data_path,stream=True)
file_name  = 'data_files.zip'
with open(file_name, 'wb') as f:
    for chunk in get_response.iter_content(chunk_size=1024):
        if chunk: # filter out keep-alive new chunks
            f.write(chunk)
maps = {}
with zipfile.ZipFile(file_name) as zip:
    files = zip.namelist()
    files.remove('readme.txt')
    # files.reverse()

    for filename in files:
        print(filename)
        raw_df = parse_data(filename, zip)
        df = raw_df[raw_df['powiat_miasto']!='Cały kraj']

        df = pd.merge(df, province_df, how='left', left_on=['wojewodztwo'], right_on=['province_name'])
        df = pd.merge(df, district_df, how='left', left_on=['id_province', 'powiat_miasto'], right_on=['id_province', 'district_name'])

        df['id_district'] = df['id_district'].astype('Int64')
        df['id_province'] = df['id_province'].astype('Int64')
        df['id_cntry'] = 136
        df['day'] = datetime.strptime(filename[:8],'%Y%m%d').strftime('%Y-%m-%d')
        if 'liczba_ozdrowiencow' not in df.columns:
            df['liczba_ozdrowiencow'] = None
        df.rename(inplace=True, columns={
            "liczba_przypadkow": "cases",
            "zgony": "deaths",
            "liczba_ozdrowiencow": "recovered"
        })
        df = df[['day','id_cntry','id_province','id_district', 'cases', 'deaths', 'recovered']]
        maps[filename] = len(df.index)
        df.to_sql('cases', db, if_exists='append', index=False)

sum(v for k,v in maps.items())
# Out:
# 20201124060000_rap_rcb_pow_eksport.csv
# 20201125060000_rap_rcb_pow_eksport.csv
# 20201126060000_rap_rcb_pow_eksport.csv
# 20201127060000_rap_rcb_pow_eksport.csv
# 20201128060000_rap_rcb_pow_eksport.csv
# 20201129060000_rap_rcb_pow_eksport.csv
# 20201130060000_rap_rcb_pow_eksport.csv
# 20201201060000_rap_rcb_pow_eksport.csv
# 20201202060000_rap_rcb_pow_eksport.csv
# 20201203060000_rap_rcb_pow_eksport.csv
# 20201204060000_rap_rcb_pow_eksport.csv
# 20201205060000_rap_rcb_pow_eksport.csv
# 20201206060000_rap_rcb_pow_eksport.csv
# 20201207060000_rap_rcb_pow_eksport.csv
# 20201208060000_rap_rcb_pow_eksport.csv
# 20201209060000_rap_rcb_pow_eksport.csv
# 20201210060000_rap_rcb_pow_eksport.csv
# 20201211060000_rap_rcb_pow_eksport.csv
# 20201212060000_rap_rcb_pow_eksport.csv
# 20201213060000_rap_rcb_pow_eksport.csv
# 20201214060000_rap_rcb_pow_eksport.csv
# 20201215060000_rap_rcb_pow_eksport.csv
# 20201216060000_rap_rcb_pow_eksport.csv
# 20201217060000_rap_rcb_pow_eksport.csv
# 20201218060000_rap_rcb_pow_eksport.csv
# 20201219060000_rap_rcb_pow_eksport.csv
# 20201220060000_rap_rcb_pow_eksport.csv
# 20201221060000_rap_rcb_pow_eksport.csv
# 20201222060000_rap_rcb_pow_eksport.csv
# 20201223060000_rap_rcb_pow_eksport.csv
# 20201224150428_rap_rcb_pow_eksport.csv
# 20201225054502_rap_rcb_pow_eksport.csv
# 20201226054502_rap_rcb_pow_eksport.csv
# 20201227054502_rap_rcb_pow_eksport.csv
# 20201228054503_rap_rcb_pow_eksport.csv
# 20201229054505_rap_rcb_pow_eksport.csv
# 20201230064728_rap_rcb_pow_eksport.csv
# 20201231054502_rap_rcb_pow_eksport.csv
# 20210101054501_rap_rcb_pow_eksport.csv
# 20210102054502_rap_rcb_pow_eksport.csv
# 20210103054501_rap_rcb_pow_eksport.csv
# 20210104054501_rap_rcb_pow_eksport.csv
# 20210105054502_rap_rcb_pow_eksport.csv
# 20210106054501_rap_rcb_pow_eksport.csv
# 20210107054535_rap_gov_pow_eksport.csv
# 20210108054501_rap_rcb_pow_eksport.csv
# 20210109054501_rap_rcb_pow_eksport.csv
# 20210110054501_rap_rcb_pow_eksport.csv
# 20210111054501_rap_rcb_pow_eksport.csv
# 20210112054502_rap_rcb_pow_eksport.csv
# 20210113054502_rap_rcb_pow_eksport.csv
# 20210114054502_rap_rcb_pow_eksport.csv
# 20210115054502_rap_rcb_pow_eksport.csv
# 20210116054502_rap_rcb_pow_eksport.csv
# 20210117054502_rap_rcb_pow_eksport.csv
# 20210118054503_rap_rcb_pow_eksport.csv
# 20210119054501_rap_rcb_pow_eksport.csv
# 20210120054502_rap_rcb_pow_eksport.csv
# 20210121054502_rap_rcb_pow_eksport.csv
# 20210122054501_rap_rcb_pow_eksport.csv
# 20210123054502_rap_rcb_pow_eksport.csv
# 20210124054502_rap_rcb_pow_eksport.csv
# 20210125083606_rap_rcb_pow_eksport.csv
# 20210126054502_rap_rcb_pow_eksport.csv
# 20210127054502_rap_rcb_pow_eksport.csv
# 20210128054501_rap_rcb_pow_eksport.csv
# 20210129083554_rap_rcb_pow_eksport.csv
# 20210130054502_rap_rcb_pow_eksport.csv
# 20210131054501_rap_rcb_pow_eksport.csv
# 20210201054502_rap_rcb_pow_eksport.csv
# 20210202054502_rap_rcb_pow_eksport.csv
# 20210203054502_rap_rcb_pow_eksport.csv
# 20210204054502_rap_rcb_pow_eksport.csv
# 20210205054502_rap_rcb_pow_eksport.csv
# 20210206054518_rap_rcb_pow_eksport.csv
# 20210207054501_rap_rcb_pow_eksport.csv
# 20210208054501_rap_rcb_pow_eksport.csv
# 20210209054501_rap_rcb_pow_eksport.csv
# 20210210054501_rap_rcb_pow_eksport.csv
# 20210211065724_rap_rcb_pow_eksport.csv
# 20210212054502_rap_rcb_pow_eksport.csv
# 20210213054502_rap_rcb_pow_eksport.csv
# 20210214054502_rap_rcb_pow_eksport.csv
# 20210215054502_rap_rcb_pow_eksport.csv
# 20210216054501_rap_rcb_pow_eksport.csv
# 20210217054502_rap_rcb_pow_eksport.csv
# 20210218054502_rap_rcb_pow_eksport.csv
# 20210219054501_rap_rcb_pow_eksport.csv
# 20210220054501_rap_rcb_pow_eksport.csv
# 20210221054502_rap_rcb_pow_eksport.csv
# 20210222054503_rap_rcb_pow_eksport.csv
# 20210223054502_rap_rcb_pow_eksport.csv
# 20210224054502_rap_rcb_pow_eksport.csv
# 20210225074502_rap_rcb_pow_eksport.csv
# 20210226074502_rap_rcb_pow_eksport.csv
# 20210227074502_rap_rcb_pow_eksport.csv
# 20210228074502_rap_rcb_pow_eksport.csv
# 20210301074502_rap_rcb_pow_eksport.csv
# 20210302074502_rap_rcb_pow_eksport.csv
# 20210303074502_rap_rcb_pow_eksport.csv
# 20210304074501_rap_rcb_pow_eksport.csv
# 20210305074502_rap_rcb_pow_eksport.csv
# 20210306074502_rap_rcb_pow_eksport.csv
# 20210307074502_rap_rcb_pow_eksport.csv
# 20210308074502_rap_rcb_pow_eksport.csv
# 20210309074502_rap_rcb_pow_eksport.csv
# 20210310074502_rap_rcb_pow_eksport.csv
# 20210311074502_rap_rcb_pow_eksport.csv
# 20210312074502_rap_rcb_pow_eksport.csv
# 20210313074503_rap_rcb_pow_eksport.csv
# 20210314074502_rap_rcb_pow_eksport.csv
# 20210315074502_rap_rcb_pow_eksport.csv
# 20210316074503_rap_rcb_pow_eksport.csv
# 20210317074502_rap_rcb_pow_eksport.csv
# 20210318074502_rap_rcb_pow_eksport.csv
# 20210319074502_rap_rcb_pow_eksport.csv
# 20210320074502_rap_rcb_pow_eksport.csv
# 20210321075502_rap_rcb_pow_eksport.csv
# 20210322075502_rap_rcb_pow_eksport.csv
# 20210323074503_rap_rcb_pow_eksport.csv
# 20210324074502_rap_rcb_pow_eksport.csv
# 20210325074502_rap_rcb_pow_eksport.csv
# 20210326074502_rap_rcb_pow_eksport.csv
# 20210327074502_rap_rcb_pow_eksport.csv
# 20210328074502_rap_rcb_pow_eksport.csv
# 20210329074502_rap_rcb_pow_eksport.csv
# 20210330074502_rap_rcb_pow_eksport.csv
# 20210331074503_rap_rcb_pow_eksport.csv
# 20210401074502_rap_rcb_pow_eksport.csv
# 20210402074503_rap_rcb_pow_eksport.csv
# 20210403074503_rap_rcb_pow_eksport.csv
# 20210404074504_rap_rcb_pow_eksport.csv
# 20210405074503_rap_rcb_pow_eksport.csv
# 20210406074503_rap_rcb_pow_eksport.csv
# 20210407074504_rap_rcb_pow_eksport.csv
# 20210408074503_rap_rcb_pow_eksport.csv
# 20210409074503_rap_rcb_pow_eksport.csv
# 20210410074502_rap_rcb_pow_eksport.csv
# 20210411074502_rap_rcb_pow_eksport.csv
# 20210412074503_rap_rcb_pow_eksport.csv
# 20210413074504_rap_rcb_pow_eksport.csv
# 20210414074503_rap_rcb_pow_eksport.csv
# 20210415074503_rap_rcb_pow_eksport.csv
# 20210416074503_rap_rcb_pow_eksport.csv
# 20210417074502_rap_rcb_pow_eksport.csv
# 20210418074502_rap_rcb_pow_eksport.csv
# 20210419074502_rap_rcb_pow_eksport.csv
# 20210420074502_rap_rcb_pow_eksport.csv
# 20210421074502_rap_rcb_pow_eksport.csv
# 20210422074503_rap_rcb_pow_eksport.csv
# 20210423074502_rap_rcb_pow_eksport.csv
# 20210424074502_rap_rcb_pow_eksport.csv
# 20210425074502_rap_rcb_pow_eksport.csv
# 20210426074502_rap_rcb_pow_eksport.csv
# 20210427074503_rap_rcb_pow_eksport.csv
# 20210428074502_rap_rcb_pow_eksport.csv
# 20210429074503_rap_rcb_pow_eksport.csv
# 20210430074502_rap_rcb_pow_eksport.csv
# 20210501074502_rap_rcb_pow_eksport.csv
# 20210502074502_rap_rcb_pow_eksport.csv
# 20210503074502_rap_rcb_pow_eksport.csv
# 20210504074502_rap_rcb_pow_eksport.csv
# 20210505074502_rap_rcb_pow_eksport.csv
# 20210506074502_rap_rcb_pow_eksport.csv
# 20210507074502_rap_rcb_pow_eksport.csv
# 20210508074502_rap_rcb_pow_eksport.csv
# 20210509074502_rap_rcb_pow_eksport.csv
# 20210510074502_rap_rcb_pow_eksport.csv
# 20210511074502_rap_rcb_pow_eksport.csv
# 20210512074503_rap_rcb_pow_eksport.csv
# 20210513074503_rap_rcb_pow_eksport.csv
# 20210514074503_rap_rcb_pow_eksport.csv
# 20210515074504_rap_rcb_pow_eksport.csv
# 20210516074503_rap_rcb_pow_eksport.csv
# 20210517074503_rap_rcb_pow_eksport.csv
# 20210518074503_rap_rcb_pow_eksport.csv
# 20210519074502_rap_rcb_pow_eksport.csv
# 20210520074502_rap_rcb_pow_eksport.csv
# 20210521074506_rap_rcb_pow_eksport.csv
# 20210522074504_rap_rcb_pow_eksport.csv
# 20210523074503_rap_rcb_pow_eksport.csv
# 20210524074503_rap_rcb_pow_eksport.csv
# 20210525074504_rap_rcb_pow_eksport.csv
# 20210526074502_rap_rcb_pow_eksport.csv
# 20210527074502_rap_rcb_pow_eksport.csv
# 20210528074503_rap_rcb_pow_eksport.csv
# 20210529074503_rap_rcb_pow_eksport.csv
# 20210530074502_rap_rcb_pow_eksport.csv
# 20210531074503_rap_rcb_pow_eksport.csv
# 20210601074502_rap_rcb_pow_eksport.csv
# 20210602074502_rap_rcb_pow_eksport.csv
# 20210603074501_rap_rcb_pow_eksport.csv
# 20210604074502_rap_rcb_pow_eksport.csv
# 20210605074502_rap_rcb_pow_eksport.csv
# 20210606074503_rap_rcb_pow_eksport.csv
# 20210607074502_rap_rcb_pow_eksport.csv
# 20210608074503_rap_rcb_pow_eksport.csv
# 20210609074500_rap_rcb_pow_eksport.csv
# 20210610074859_rap_rcb_pow_eksport.csv
# 20210611074500_rap_rcb_pow_eksport.csv
# 20210612074500_rap_rcb_pow_eksport.csv
# 20210613074500_rap_rcb_pow_eksport.csv
# 20210614074500_rap_rcb_pow_eksport.csv
# 20210615074500_rap_rcb_pow_eksport.csv
# 20210616074500_rap_rcb_pow_eksport.csv
# 20210617074500_rap_rcb_pow_eksport.csv
# 20210618074650_rap_rcb_pow_eksport.csv
# 20210619074851_rap_rcb_pow_eksport.csv
# 20210620074834_rap_rcb_pow_eksport.csv
# 20210621080306_rap_rcb_pow_eksport.csv
# 20210622082023_rap_rcb_pow_eksport.csv
# 20210623075822_rap_rcb_pow_eksport.csv
# 20210624075124_rap_rcb_pow_eksport.csv
# 20210625074543_rap_rcb_pow_eksport.csv
# 20210626080734_rap_rcb_pow_eksport.csv
# 20210627074501_rap_rcb_pow_eksport.csv
# 20210628074500_rap_rcb_pow_eksport.csv
# 20210629074501_rap_rcb_pow_eksport.csv
# 20210630074500_rap_rcb_pow_eksport.csv
# 20210701074500_rap_rcb_pow_eksport.csv
# 20210702074542_rap_rcb_pow_eksport.csv
# 20210703075258_rap_rcb_pow_eksport.csv
# 20210704075318_rap_rcb_pow_eksport.csv
# 20210705074503_rap_rcb_pow_eksport.csv
# 20210706074504_rap_rcb_pow_eksport.csv
# 20210707075941_rap_rcb_pow_eksport.csv
# 20210708080734_rap_rcb_pow_eksport.csv
# 20210709075516_rap_rcb_pow_eksport.csv
# 20210710080311_rap_rcb_pow_eksport.csv
# 20210711075129_rap_rcb_pow_eksport.csv
# 20210712083111_rap_rcb_pow_eksport.csv
# 20210713081902_rap_rcb_pow_eksport.csv
# 20210714074501_rap_rcb_pow_eksport.csv
# 20210715074501_rap_rcb_pow_eksport.csv
# 20210716074501_rap_rcb_pow_eksport.csv
# 20210717074501_rap_rcb_pow_eksport.csv
# 20210718084501_rap_rcb_pow_eksport.csv
# 20210719074501_rap_rcb_pow_eksport.csv
# 20210720074501_rap_rcb_pow_eksport.csv
# 20210721074501_rap_rcb_pow_eksport.csv
# 20210722074501_rap_rcb_pow_eksport.csv
# 20210723074501_rap_rcb_pow_eksport.csv
# 20210724074501_rap_rcb_pow_eksport.csv
# 20210725074501_rap_rcb_pow_eksport.csv
# 20210726074502_rap_rcb_pow_eksport.csv
# 20210727074501_rap_rcb_pow_eksport.csv
# 20210728074502_rap_rcb_pow_eksport.csv
# 20210729074501_rap_rcb_pow_eksport.csv
# 20210730074502_rap_rcb_pow_eksport.csv
# 20210731074502_rap_rcb_pow_eksport.csv
# 20210801074502_rap_rcb_pow_eksport.csv
# 20210802074502_rap_rcb_pow_eksport.csv
# 20210803074502_rap_rcb_pow_eksport.csv
# 20210804074502_rap_rcb_pow_eksport.csv
# 20210805074501_rap_rcb_pow_eksport.csv
# 20210806074501_rap_rcb_pow_eksport.csv
# 20210807074502_rap_rcb_pow_eksport.csv
# 20210808074501_rap_rcb_pow_eksport.csv
# 20210809074501_rap_rcb_pow_eksport.csv
# 20210810074502_rap_rcb_pow_eksport.csv
# 20210811074501_rap_rcb_pow_eksport.csv
# 20210812074502_rap_rcb_pow_eksport.csv
# 20210813074501_rap_rcb_pow_eksport.csv
# 20210814074504_rap_rcb_pow_eksport.csv
# 20210815074501_rap_rcb_pow_eksport.csv
# 20210816074501_rap_rcb_pow_eksport.csv
# 20210817074501_rap_rcb_pow_eksport.csv
# 20210818074502_rap_rcb_pow_eksport.csv
# 20210819074501_rap_rcb_pow_eksport.csv
# 20210820074501_rap_rcb_pow_eksport.csv
# 20210821090633_rap_rcb_pow_eksport.csv
# 20210822074501_rap_rcb_pow_eksport.csv
# 20210823074501_rap_rcb_pow_eksport.csv
# 20210824074501_rap_rcb_pow_eksport.csv
# 20210825074502_rap_rcb_pow_eksport.csv
# 20210826074502_rap_rcb_pow_eksport.csv
# 20210827074502_rap_rcb_pow_eksport.csv
# 20210828074502_rap_rcb_pow_eksport.csv
# 20210829074502_rap_rcb_pow_eksport.csv
# 20210830074505_rap_rcb_pow_eksport.csv
# 20210831074505_rap_rcb_pow_eksport.csv
# 20210901074559_rap_rcb_pow_eksport.csv
# 20210902074502_rap_rcb_pow_eksport.csv
# 20210903074502_rap_rcb_pow_eksport.csv
# 20210904074502_rap_rcb_pow_eksport.csv
# 20210905074502_rap_rcb_pow_eksport.csv
# 20210906074502_rap_rcb_pow_eksport.csv
# 20210907074502_rap_rcb_pow_eksport.csv
# 20210908074502_rap_rcb_pow_eksport.csv
# 20210909074502_rap_rcb_pow_eksport.csv
# 20210910074502_rap_rcb_pow_eksport.csv
# 20210911074504_rap_rcb_pow_eksport.csv
# 20210912074505_rap_rcb_pow_eksport.csv
# 20210913074515_rap_rcb_pow_eksport.csv
# 20210914074502_rap_rcb_pow_eksport.csv
# 20210915074502_rap_rcb_pow_eksport.csv
# 20210916074502_rap_rcb_pow_eksport.csv
# 20210917074502_rap_rcb_pow_eksport.csv
# 20210918074502_rap_rcb_pow_eksport.csv
# 20210919074503_rap_rcb_pow_eksport.csv
# 20210920074502_rap_rcb_pow_eksport.csv
# 20210921074502_rap_rcb_pow_eksport.csv
# 20210922074502_rap_rcb_pow_eksport.csv
# 20210923074502_rap_rcb_pow_eksport.csv
# 20210924074508_rap_rcb_pow_eksport.csv
# 20210925074549_rap_rcb_pow_eksport.csv
# 20210926074502_rap_rcb_pow_eksport.csv
# 20210927074502_rap_rcb_pow_eksport.csv
# 20210928074501_rap_rcb_pow_eksport.csv
# 20210929074501_rap_rcb_pow_eksport.csv
# 20210930074502_rap_rcb_pow_eksport.csv
# 20211001074502_rap_rcb_pow_eksport.csv
# 20211002074502_rap_rcb_pow_eksport.csv
# 20211003074502_rap_rcb_pow_eksport.csv
# 20211004074503_rap_rcb_pow_eksport.csv
# 20211005074505_rap_rcb_pow_eksport.csv
# 20211006074502_rap_rcb_pow_eksport.csv
# 20211007074502_rap_rcb_pow_eksport.csv
# 20211008074502_rap_rcb_pow_eksport.csv
# 20211009074501_rap_rcb_pow_eksport.csv
# 20211010074502_rap_rcb_pow_eksport.csv
# 20211011074501_rap_rcb_pow_eksport.csv
# 20211012074502_rap_rcb_pow_eksport.csv
# 20211013074502_rap_rcb_pow_eksport.csv
# 20211014074502_rap_rcb_pow_eksport.csv
# 20211015074504_rap_rcb_pow_eksport.csv
# 20211016074505_rap_rcb_pow_eksport.csv
# 20211017075257_rap_rcb_pow_eksport.csv
# 20211018074501_rap_rcb_pow_eksport.csv
# 20211019074501_rap_rcb_pow_eksport.csv
# 20211020103220_rap_rcb_pow_eksport.csv
# 20211021074503_rap_rcb_pow_eksport.csv
# 20211022074501_rap_rcb_pow_eksport.csv
# 20211023074502_rap_rcb_pow_eksport.csv
# 20211024074502_rap_rcb_pow_eksport.csv
# 20211025074502_rap_rcb_pow_eksport.csv
# 20211026074503_rap_rcb_pow_eksport.csv
# 20211027074507_rap_rcb_pow_eksport.csv
# 20211028074502_rap_rcb_pow_eksport.csv
# 20211029074503_rap_rcb_pow_eksport.csv
# 20211030074502_rap_rcb_pow_eksport.csv
# 20211031074501_rap_rcb_pow_eksport.csv
# 20211101074502_rap_rcb_pow_eksport.csv
# 20211102074502_rap_rcb_pow_eksport.csv
# 20211103074502_rap_rcb_pow_eksport.csv
# 20211104074503_rap_rcb_pow_eksport.csv
# 20211105074502_rap_rcb_pow_eksport.csv
# 20211106074501_rap_rcb_pow_eksport.csv
# 20211107074501_rap_rcb_pow_eksport.csv
# 20211108074502_rap_rcb_pow_eksport.csv
# 20211109074502_rap_rcb_pow_eksport.csv
# 20211110074502_rap_rcb_pow_eksport.csv
# 20211111074502_rap_rcb_pow_eksport.csv
# 20211112074502_rap_rcb_pow_eksport.csv
# 20211113074501_rap_rcb_pow_eksport.csv
# 20211114074502_rap_rcb_pow_eksport.csv
# 20211115074502_rap_rcb_pow_eksport.csv
# 20211116074502_rap_rcb_pow_eksport.csv
# 20211117074501_rap_rcb_pow_eksport.csv
# 20211118074501_rap_rcb_pow_eksport.csv
# 20211119074501_rap_rcb_pow_eksport.csv
# 20211120074502_rap_rcb_pow_eksport.csv
# 20211121074502_rap_rcb_pow_eksport.csv
# 20211122074502_rap_rcb_pow_eksport.csv
# 20211123074502_rap_rcb_pow_eksport.csv
# 20211124074502_rap_rcb_pow_eksport.csv
# 20211125074502_rap_rcb_pow_eksport.csv
# 20211126074502_rap_rcb_pow_eksport.csv
# 20211127074501_rap_rcb_pow_eksport.csv
# 20211128074502_rap_rcb_pow_eksport.csv
# 20211129074501_rap_rcb_pow_eksport.csv
# 20211130074502_rap_rcb_pow_eksport.csv
# 20211201074501_rap_rcb_pow_eksport.csv
# 20211202074502_rap_rcb_pow_eksport.csv
# 20211203074501_rap_rcb_pow_eksport.csv
# 20211204074502_rap_rcb_pow_eksport.csv
# 20211205074502_rap_rcb_pow_eksport.csv
# 20211206074501_rap_rcb_pow_eksport.csv
# 20211207074502_rap_rcb_pow_eksport.csv
# 20211208074503_rap_rcb_pow_eksport.csv
# 20211209074502_rap_rcb_pow_eksport.csv
# 20211210074502_rap_rcb_pow_eksport.csv
# 20211211074502_rap_rcb_pow_eksport.csv
# 20211212074502_rap_rcb_pow_eksport.csv
# 20211213074502_rap_rcb_pow_eksport.csv
# 20211214074502_rap_rcb_pow_eksport.csv
# 20211215074502_rap_rcb_pow_eksport.csv
# 20211216074502_rap_rcb_pow_eksport.csv
# 20211217074502_rap_rcb_pow_eksport.csv
# 20211218074502_rap_rcb_pow_eksport.csv
# 20211219074502_rap_rcb_pow_eksport.csv
# 20211220074501_rap_rcb_pow_eksport.csv
# 20211221074502_rap_rcb_pow_eksport.csv
# 20211222074502_rap_rcb_pow_eksport.csv
# 20211223074502_rap_rcb_pow_eksport.csv
# 20211224074502_rap_rcb_pow_eksport.csv
# 20211225074502_rap_rcb_pow_eksport.csv
# 20211226074502_rap_rcb_pow_eksport.csv
# 20211227074502_rap_rcb_pow_eksport.csv
# 20211228074502_rap_rcb_pow_eksport.csv
# 20211229074502_rap_rcb_pow_eksport.csv
# 20211230074502_rap_rcb_pow_eksport.csv
# 20211231074502_rap_rcb_pow_eksport.csv
# 20220101074502_rap_rcb_pow_eksport.csv
# 20220102074502_rap_rcb_pow_eksport.csv
# 20220103074503_rap_rcb_pow_eksport.csv
# 20220104074502_rap_rcb_pow_eksport.csv
# 20220105074505_rap_rcb_pow_eksport.csv
# 20220106074503_rap_rcb_pow_eksport.csv
# 20220107074508_rap_rcb_pow_eksport.csv
# 20220108074502_rap_rcb_pow_eksport.csv
# 20220109074502_rap_rcb_pow_eksport.csv
# 20220110074502_rap_rcb_pow_eksport.csv
# 20220111074502_rap_rcb_pow_eksport.csv
# 20220112074502_rap_rcb_pow_eksport.csv
# 157700
